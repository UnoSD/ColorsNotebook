# %%
#r "nuget: Plotly.NET, 5.1.0"
#r "nuget: Plotly.NET.Interactive, 5.0.0"
#r "nuget: FSharp.Data, 6.6.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>FSharp.Data, 6.6.0</span></li><li><span>Plotly.NET, 5.1.0</span></li><li><span>Plotly.NET.Interactive, 5.0.0</span></li></ul></div></div>
# Loading extensions from `C:\Users\stefdantonio.EUROPE\.nuget\packages\plotly.net.interactive\5.0.0\lib\netstandard2.1\Plotly.NET.Interactive.dll`

# %%
open System.Drawing

let rgbToHsl (color : Color) =
    // Normalize R, G, B in the range [0..1]
    let r = float color.R / 255.0
    let g = float color.G / 255.0
    let b = float color.B / 255.0
    
    // Find min and max values among R, G, B
    let cMax = max g b |> max r
    let cMin = min g b |> min r
    let delta = cMax - cMin
    
    // Calculate lightness
    let l = (cMax + cMin) / 2.0
    
    // If all channels are the same, it's a shade of gray => S=0, H=0
    if delta = 0.0 then
        (0.0, 0.0, l)
    else
        // Calculate saturation
        let s =
            if l < 0.5 then
                delta / (cMax + cMin)
            else
                delta / (2.0 - cMax - cMin)
        
        // Calculate hue (base formula gives result in [0..6], we turn it into degrees [0..360])
        let hBase =
            match cMax with
            | _ when r = cMax -> (g - b) / delta % 6.0
            | _ when g = cMax -> (b - r) / delta + 2.0
            | _               -> (r - g) / delta + 4.0
        
        // Convert hBase to degrees: multiply by 60
        // ensure non-negative by adding 360 if negative
        let hDegrees =
            let raw = 60.0 * hBase
            if raw < 0.0 then raw + 360.0 else raw
        
        (hDegrees, s, l)

# %%
open FSharp.Data
open System.Drawing

let colorsCsvPath =
    System.IO.Directory.GetCurrentDirectory() + "/MaxMeyer.csv"

type MaxMeyerColor =
    { Name : string; Code : string; Color : Color }

let colorToHtml color =
    $"""<p>{color.Name}<br>{color.Code}<br>{color.Color.Name}</p>
        <svg width="300"
             height="200">
          <rect width="300" 
                height="200" 
                style="fill:rgb({color.Color.R},{color.Color.G},{color.Color.B})" />
        </svg>"""

let colorOptionToHtml =
    function
    | Some c -> c
    | None   -> { Name = "Not found"; Code = "N/A"; Color = Color.Black }
    >> colorToHtml

Formatter.Register<MaxMeyerColor>(colorToHtml, "text/html")
Formatter.Register<MaxMeyerColor option>(colorOptionToHtml, "text/html")
Formatter.Register<MaxMeyerColor option array>(
    (Array.map (colorOptionToHtml >> sprintf """<td>%s</td>""")
     >> Array.chunkBySize 5
     >> Array.map (String.concat "" >> sprintf "<tr>%s</tr>")
     >> String.concat ""
     >> fun rows -> $"<table>{rows}</table>"), 
    "text/html")

let colors =
    CsvFile.Load(colorsCsvPath).Rows
    |> Seq.map (fun row -> {
        Name  = if String.IsNullOrEmpty row.Columns[0] then row.Columns[1] else row.Columns[0]
        Code  = row.Columns[1]
        Color = Color.FromArgb(0, int row.Columns[2], int row.Columns[3], int row.Columns[4])})
    |> Array.ofSeq
    
let findColor (name : string) =
    let lowerName =
        name.ToLower()
    
    let tryFindMatchOn f () =
        Array.tryFind (fun color -> f color lowerName) colors

    colors
    |> Array.tryFind _.Name.ToLower().Contains(lowerName)
    |> Option.orElseWith (tryFindMatchOn _.Code.ToLower().Contains)
    |> Option.orElseWith (tryFindMatchOn _.Color.Name.ToLower().Contains)
    |> Option.orElseWith (tryFindMatchOn (fun color name -> $"{color.Color.R} {color.Color.G} {color.Color.B}" = name))

let findClosestColors mmColor =
    let r, g, b =
        mmColor.Color.R, mmColor.Color.G, mmColor.Color.B
    
    colors
    |> Array.sortBy (fun mmc ->
        let dR, dG, dB = 
            mmc.Color.R - r, mmc.Color.G - g, mmc.Color.B - b
        dR*dR + dG*dG + dB*dB)

let findClosestColorsHsl mmColor =
    let h, s, l =
        rgbToHsl mmColor.Color

    colors
    |> Array.sortBy (fun mmc ->
        let mh, ms, ml =
            rgbToHsl mmc.Color
        let dH = mh - h
        let dS = ms - s
        let dL = ml - l
        dH*dH + dS*dS + dL*dL)

let findClosestColorsHslFromName name =
    findColor name
    |> Option.map findClosestColorsHsl
    |> Option.defaultValue [||]

# %%
let colors = [|
    "cactus"
    "MAX19-0943"
|]

colors
|> Array.map findColor
# Out:
# <table><tr><td><p>MAX19-0942<br>Cactus<br>6d7a5c</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(109,122,92)" />
#         </svg></td><td><p>MAX19-0943<br>Aroma<br>5a674d</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(90,103,77)" />
#         </svg></td></tr></table>

# %%
findClosestColorsHslFromName "cactus"
|> Array.take 60
|> Array.map Some
# Out:
# <table><tr><td><p>MAX19-0942<br>Cactus<br>6d7a5c</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(109,122,92)" />
#         </svg></td><td><p>MAX19-0928<br>Verde Chiaro<br>82b73c</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(130,183,60)" />
#         </svg></td><td><p>MAX19-1093<br>Zebu<br>cfd5c7</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(207,213,199)" />
#         </svg></td><td><p>MAX19-0995<br>Fumo Verde<br>cfd5c7</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(207,213,199)" />
#         </svg></td><td><p>MAX19-0922<br>Dollaro<br>506d29</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(80,109,41)" />
#         </svg></td></tr><tr><td><p>MAX19-0919<br>Verde Pop<br>82af49</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(130,175,73)" />
#         </svg></td><td><p>MAX19-0933<br>Flanella<br>bcd997</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(188,217,151)" />
#         </svg></td><td><p>MAX19-0940<br>Flora<br>b9cca1</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(185,204,161)" />
#         </svg></td><td><p>CRF088-1<br>CRF088-1<br>b0c09c</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(176,192,156)" />
#         </svg></td><td><p>MAX19-0930<br>Verde Latifoglie<br>5a8025</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(90,128,37)" />
#         </svg></td></tr><tr><td><p>MAX19-0054<br>Medicina<br>d8ddd1</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(216,221,209)" />
#         </svg></td><td><p>MAX19-0920<br>granny smith<br>75934a</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(117,147,74)" />
#         </svg></td><td><p>MAX19-0912<br>Finocchio<br>aacf7e</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(170,207,126)" />
#         </svg></td><td><p>Verde<br>Verde<br>7ead3a</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(126,173,58)" />
#         </svg></td><td><p>MAX19-0921<br>La Sera dei Miracoli<br>5a7639</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(90,118,57)" />
#         </svg></td></tr><tr><td><p>MAX19-0931<br>Friariello<br>4e7a1a</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(78,122,26)" />
#         </svg></td><td><p>MAX19-0913<br>Ondulato<br>9ec176</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(158,193,118)" />
#         </svg></td><td><p>MAX19-0927<br>Verde Selvaggio<br>96c254</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(150,194,84)" />
#         </svg></td><td><p>MAX19-0916<br>Cerfoglio<br>556b3c</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(85,107,60)" />
#         </svg></td><td><p>MAX19-0926<br>Tea tree<br>a2c967</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(162,201,103)" />
#         </svg></td></tr><tr><td><p>MAX19-0938<br>Primavera<br>4b5b39</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(75,91,57)" />
#         </svg></td><td><p>MAX19-0941<br>Soprabosco<br>849571</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(132,149,113)" />
#         </svg></td><td><p>MAX19-0944<br>Orgosolo<br>444f38</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(68,79,56)" />
#         </svg></td><td><p>MAX19-0935<br>Aloe<br>8da672</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(141,166,114)" />
#         </svg></td><td><p>MAX19-0914<br>Sospetto<br>7f9f5d</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(127,159,93)" />
#         </svg></td></tr><tr><td><p>MAX19-0929<br>Verde Luminoso<br>74a81e</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(116,168,30)" />
#         </svg></td><td><p>MAX19-0943<br>Aroma<br>5a674d</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(90,103,77)" />
#         </svg></td><td><p>MAX19-0936<br>Verde Stagnante<br>758c5e</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(117,140,94)" />
#         </svg></td><td><p>MAX19-0937<br>lacerta<br>5f724c</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(95,114,76)" />
#         </svg></td><td><p>CRF0117-1<br>CRF0117-1<br>71736f</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(113,115,111)" />
#         </svg></td></tr><tr><td><p>MAX19-0915<br>Green Wheels<br>68844c</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(104,132,76)" />
#         </svg></td><td><p>MAX19-0917<br>Agata<br>3f522c</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(63,82,44)" />
#         </svg></td><td><p>MAX19-0934<br>Pigiama<br>a5c288</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(165,194,136)" />
#         </svg></td><td><p>MAX19-0890<br>Panna Cotta<br>c6d2ba</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(198,210,186)" />
#         </svg></td><td><p>Grigio<br>Grigio<br>e9eae8</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
#                 height="200"
#                 style="fill:rgb(233,234,232)" />
#         </svg></td></tr><tr><td><p>CRF004-1<br>CRF004-1<br>fcfefa</p>
#         <svg width="300"
#              height="200">
#           <rect width="300"
